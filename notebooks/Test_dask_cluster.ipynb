# %%
from dask.distributed import Client, LocalCluster

cluster = LocalCluster(processes=False, n_workers=3)
client = Client(cluster)
client
# Out:
# C:\Users\xavier.mouy\Anaconda3\envs\ecosound\lib\site-packages\distributed\node.py:244: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 60932 instead
#   http_address["port"], self.http_server.port
# <Client: 'inproc://192.168.0.28/16140/1' processes=3 threads=6, memory=16.86 GB>

# %%
import sys
sys.path.append("..")  # Adds higher directory to python modules path.
from ecosound.core.audiotools import Sound
from ecosound.core.spectrogram import Spectrogram
from ecosound.core.annotation import Annotation
from ecosound.detection.detector_builder import DetectorFactory
from ecosound.visualization.grapher_builder import GrapherFactory
from ecosound.measurements.measurer_builder import MeasurerFactory
import ecosound.core.tools
import time
import os

# %%
def run_detector(infile, outdir):
    ## Input paraneters ##########################################################   
    
    
    # Spectrogram parameters
    frame = 3000
    nfft = 4096
    step = 500
    fmin = 0
    fmax = 1000
    window_type = 'hann'

    # start and stop time of wavfile to analyze
    #t1 = 0 # 24
    #t2 = 60 # 40
    ## ###########################################################################
    outfile = os.path.join(outdir, os.path.split(file)[1]+'.nc')
    
    if os.path.exists(outfile) is False:
        # load audio data
        sound = Sound(infile)
        #sound.read(channel=0, chunk=[t1, t2], unit='sec')
        sound.read(channel=0, unit='sec')
        # Calculates  spectrogram
        spectro = Spectrogram(frame, window_type, nfft, step, sound.waveform_sampling_frequency, unit='samp')
        spectro.compute(sound, dB=True, use_dask=True, dask_chunks=40)
        # Crop unused frequencies
        spectro.crop(frequency_min=fmin, frequency_max=fmax, inplace=True)
        # Denoise
        spectro.denoise('median_equalizer',
                        window_duration=3,
                        use_dask=True,
                        dask_chunks=(2048,1000),
                        inplace=True)
        # Detector
        file_timestamp = ecosound.core.tools.filename_to_datetime(infile)[0]
        detector = DetectorFactory('BlobDetector',
                                   kernel_duration=0.1,
                                   kernel_bandwidth=300,
                                   threshold=10,
                                   duration_min=0.05,
                                   bandwidth_min=40)
        detections = detector.run(spectro,
                                  start_time=file_timestamp,
                                  use_dask=True,
                                  dask_chunks=(2048,1000),
                                  debug=False)
        # Maasurements
        spectro_features = MeasurerFactory('SpectrogramFeatures', resolution_time=0.001, resolution_freq=0.1, interp='linear')
        measurements = spectro_features.compute(spectro,
                                                detections,
                                                debug=False,
                                                verbose=False,
                                                use_dask=True)
        measurements.to_netcdf(outfile)
    else:
        print('Recording already processed.')

# %%
indir = r'C:\Users\xavier.mouy\Documents\PhD\Projects\Dectector\datasets'
outdir=r'C:\Users\xavier.mouy\Documents\PhD\Projects\Dectector\results\Full_dataset2'
ext='.wav'

files = ecosound.core.tools.list_files(indir,
                                        ext,
                                        recursive=True,
                                        case_sensitive=True)

for idx,  file in enumerate(files):
    print(str(idx)+r'/'+str(len(files))+': '+ file)
    try:
        tic = time.perf_counter()
        run_detector(file, outdir)
        toc = time.perf_counter()
    except:
        print('ERROR HERE --------------------------------------')
            
    print(f"Executed in {toc - tic:0.4f} seconds")
# Out:
# 0/229: C:\Users\xavier.mouy\Documents\PhD\Projects\Dectector\datasets\DFO_snake-island_rca-in_20181017\audio_data\67674121.181017000806.wav
# C:\Users\xavier.mouy\Anaconda3\envs\ecosound\lib\site-packages\distributed\worker.py:3379: UserWarning: Large object of size 17.36 MB detected in task graph:
#   (array([0.01400757, 0.0140686 , 0.01409912, ..., 0 ... 162500]), 4096)
# Consider scattering large objects ahead of time
# with client.scatter to reduce scheduler burden and
# keep data on workers
#
#     future = client.submit(func, big_data)    # bad
#
#     big_future = client.scatter(big_data)     # good
#     future = client.submit(func, big_future)  # good
#   % (format_bytes(len(b)), s)
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 3.52 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 3.48 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Worker is at 91% memory usage. Pausing worker.  Process memory: 5.14 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Worker is at 91% memory usage. Pausing worker.  Process memory: 5.15 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Worker is at 91% memory usage. Pausing worker.  Process memory: 5.15 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.75 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 8.00 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 7.99 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 8.65 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 8.70 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 8.71 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 8.71 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 8.71 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 8.71 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 8.71 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 8.42 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 8.42 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 8.42 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 8.67 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 8.67 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 8.67 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 8.67 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 8.68 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 8.68 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 8.90 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 8.91 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 8.91 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.00 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.00 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.00 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.05 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.06 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.06 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.09 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.09 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.09 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.14 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.14 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.14 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.17 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.17 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.17 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.22 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.22 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.22 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.25 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.25 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.25 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.26 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.26 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.26 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.27 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.27 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.27 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.28 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.28 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.28 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.28 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.28 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.28 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.27 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.27 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.27 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.27 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.27 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.27 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.27 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.27 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.27 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.27 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.27 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.27 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.27 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.27 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.27 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.27 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.27 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.27 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.27 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.27 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.27 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.21 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.21 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.21 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Worker is at 60% memory usage. Resuming worker. Process memory: 3.41 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Worker is at 60% memory usage. Resuming worker. Process memory: 3.41 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Worker is at 60% memory usage. Resuming worker. Process memory: 3.41 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 4.01 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 4.37 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Worker is at 90% memory usage. Pausing worker.  Process memory: 5.09 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 5.09 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Worker is at 109% memory usage. Pausing worker.  Process memory: 6.18 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 6.18 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Worker is at 137% memory usage. Pausing worker.  Process memory: 7.74 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 7.74 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 9.16 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 8.61 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 8.61 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 8.79 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 8.36 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 8.26 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 8.28 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 8.60 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 8.69 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.78 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.99 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.07 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.19 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.55 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.50 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.61 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.87 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 10.72 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 11.61 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 11.72 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 11.89 GB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 289.61 MB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 290.10 MB -- Worker memory limit: 5.62 GB
# distributed.worker - WARNING - Worker is at 5% memory usage. Resuming worker. Process memory: 290.20 MB -- Worker memory limit: 5.62 GB
# ERROR HERE --------------------------------------
# distributed.utils - ERROR - Timed out trying to connect to 'inproc://192.168.0.28/16140/4' after 10 s: Timed out trying to connect to 'inproc://192.168.0.28/16140/4' after 10 s: connect() didn't finish in time
# Traceback (most recent call last):
#   File "C:\Users\xavier.mouy\Anaconda3\envs\ecosound\lib\site-packages\distributed\comm\core.py", line 232, in connect
#     _raise(error)
#   File "C:\Users\xavier.mouy\Anaconda3\envs\ecosound\lib\site-packages\distributed\comm\core.py", line 213, in _raise
#     raise IOError(msg)
# OSError: Timed out trying to connect to 'inproc://192.168.0.28/16140/4' after 10 s: connect() didn't finish in time
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xavier.mouy\Anaconda3\envs\ecosound\lib\site-packages\distributed\utils.py", line 664, in log_errors
#     yield
#   File "C:\Users\xavier.mouy\Anaconda3\envs\ecosound\lib\site-packages\distributed\dashboard\components\shared.py", line 325, in cb
#     key=self.key, start=self.start, stop=self.stop
#   File "C:\Users\xavier.mouy\Anaconda3\envs\ecosound\lib\site-packages\distributed\scheduler.py", line 4972, in get_profile
#     for w in workers
#   File "C:\Users\xavier.mouy\Anaconda3\envs\ecosound\lib\site-packages\distributed\core.py", line 747, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#   File "C:\Users\xavier.mouy\Anaconda3\envs\ecosound\lib\site-packages\distributed\core.py", line 900, in connect
#     **self.connection_args,
#   File "C:\Users\xavier.mouy\Anaconda3\envs\ecosound\lib\site-packages\distributed\comm\core.py", line 243, in connect
#     _raise(error)
#   File "C:\Users\xavier.mouy\Anaconda3\envs\ecosound\lib\site-packages\distributed\comm\core.py", line 213, in _raise
#     raise IOError(msg)
# OSError: Timed out trying to connect to 'inproc://192.168.0.28/16140/4' after 10 s: Timed out trying to connect to 'inproc://192.168.0.28/16140/4' after 10 s: connect() didn't finish in time
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x000001F932D86208>>, <Task finished coro=<ProfileTimePlot.trigger_update.<locals>.cb() done, defined at C:\Users\xavier.mouy\Anaconda3\envs\ecosound\lib\site-packages\distributed\dashboard\components\shared.py:322> exception=OSError("Timed out trying to connect to 'inproc://192.168.0.28/16140/4' after 10 s: Timed out trying to connect to 'inproc://192.168.0.28/16140/4' after 10 s: connect() didn't finish in time")>)
# Traceback (most recent call last):
#   File "C:\Users\xavier.mouy\Anaconda3\envs\ecosound\lib\site-packages\distributed\comm\core.py", line 232, in connect
#     _raise(error)
#   File "C:\Users\xavier.mouy\Anaconda3\envs\ecosound\lib\site-packages\distributed\comm\core.py", line 213, in _raise
#     raise IOError(msg)
# OSError: Timed out trying to connect to 'inproc://192.168.0.28/16140/4' after 10 s: connect() didn't finish in time
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\xavier.mouy\Anaconda3\envs\ecosound\lib\site-packages\tornado\ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "C:\Users\xavier.mouy\Anaconda3\envs\ecosound\lib\site-packages\tornado\ioloop.py", line 767, in _discard_future_result
#     future.result()
#   File "C:\Users\xavier.mouy\Anaconda3\envs\ecosound\lib\site-packages\distributed\dashboard\components\shared.py", line 325, in cb
#     key=self.key, start=self.start, stop=self.stop
#   File "C:\Users\xavier.mouy\Anaconda3\envs\ecosound\lib\site-packages\distributed\scheduler.py", line 4972, in get_profile
#     for w in workers
#   File "C:\Users\xavier.mouy\Anaconda3\envs\ecosound\lib\site-packages\distributed\core.py", line 747, in send_recv_from_rpc
#     comm = await self.pool.connect(self.addr)
#   File "C:\Users\xavier.mouy\Anaconda3\envs\ecosound\lib\site-packages\distributed\core.py", line 900, in connect
#     **self.connection_args,
#   File "C:\Users\xavier.mouy\Anaconda3\envs\ecosound\lib\site-packages\distributed\comm\core.py", line 243, in connect
#     _raise(error)
#   File "C:\Users\xavier.mouy\Anaconda3\envs\ecosound\lib\site-packages\distributed\comm\core.py", line 213, in _raise
#     raise IOError(msg)
# OSError: Timed out trying to connect to 'inproc://192.168.0.28/16140/4' after 10 s: Timed out trying to connect to 'inproc://192.168.0.28/16140/4' after 10 s: connect() didn't finish in time
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-3aa13e08450f> in <module>
#      13         tic = time.perf_counter()
# ---> 14         run_detector(file, outdir)
#      15         toc = time.perf_counter()
#
# <ipython-input-4-808bec8e4b95> in run_detector(infile, outdir)
#      53                                                 verbose=False,
# ---> 54                                                 use_dask=True)
#      55         measurements.to_netcdf(outfile)
#
# ~\Documents\Workspace\GitHub\ecosound\ecosound\measurements\spectrogram_features.py in compute(self, spectro, annotations, debug, verbose, use_dask)
#     412             #features.visualize('measuremnets')
# --> 413             features = features.compute()
#     414         else:
#
# ~\Anaconda3\envs\ecosound\lib\site-packages\dask\base.py in compute(self, **kwargs)
#     165         """
# --> 166         (result,) = compute(self, traverse=False, **kwargs)
#     167         return result
#
# ~\Anaconda3\envs\ecosound\lib\site-packages\dask\base.py in compute(*args, **kwargs)
#     443
# --> 444     results = schedule(dsk, keys, **kwargs)
#     445     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# ~\Anaconda3\envs\ecosound\lib\site-packages\distributed\client.py in get(self, dsk, keys, restrictions, loose_restrictions, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2654             user_priority=priority,
# -> 2655             actors=actors,
#    2656         )
#
# ~\Anaconda3\envs\ecosound\lib\site-packages\distributed\client.py in _graph_to_futures(self, dsk, keys, restrictions, loose_restrictions, priority, user_priority, resources, retries, fifo_timeout, actors)
#    2581                     "op": "update-graph",
# -> 2582                     "tasks": valmap(dumps_task, dsk3),
#    2583                     "dependencies": dependencies,
#
# ~\Anaconda3\envs\ecosound\lib\site-packages\cytoolz\dicttoolz.pyx in cytoolz.dicttoolz.valmap()
#
# ~\Anaconda3\envs\ecosound\lib\site-packages\cytoolz\dicttoolz.pyx in cytoolz.dicttoolz.valmap()
#
# ~\Anaconda3\envs\ecosound\lib\site-packages\distributed\worker.py in dumps_task(task)
#    3354         elif not any(map(_maybe_complex, task[1:])):
# -> 3355             return {"function": dumps_function(task[0]), "args": warn_dumps(task[1:])}
#    3356     return to_serialize(task)
#
# ~\Anaconda3\envs\ecosound\lib\site-packages\distributed\worker.py in warn_dumps(obj, dumps, limit)
#    3363     """ Dump an object to bytes, warn if those bytes are large """
# -> 3364     b = dumps(obj)
#    3365     if not _warn_dumps_warned[0] and len(b) > limit:
#
# ~\Anaconda3\envs\ecosound\lib\site-packages\distributed\protocol\pickle.py in dumps(x)
#      34         result = pickle.dumps(x, protocol=pickle.HIGHEST_PROTOCOL)
# ---> 35         if len(result) < 1000:
#      36             if b"__main__" in result:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-3aa13e08450f> in <module>
#      15         toc = time.perf_counter()
#      16     except:
# ---> 17         print('ERROR HERE --------------------------------------')
#      18
#      19     print(f"Executed in {toc - tic:0.4f} seconds")
#
# ~\Anaconda3\envs\ecosound\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     408                     self.flush()
#     409             else:
# --> 410                 self._schedule_flush()
#     411
#     412     def writelines(self, sequence):
#
# ~\Anaconda3\envs\ecosound\lib\site-packages\ipykernel\iostream.py in _schedule_flush(self)
#     332         def _schedule_in_thread():
#     333             self._io_loop.call_later(self.flush_interval, self._flush)
# --> 334         self.pub_thread.schedule(_schedule_in_thread)
#     335
#     336     def flush(self):
#
# ~\Anaconda3\envs\ecosound\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# ~\Anaconda3\envs\ecosound\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     398                                  copy_threshold=self.copy_threshold)
#     399             data.group = group
# --> 400         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     401
#     402     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~\Anaconda3\envs\ecosound\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
cluster.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f7593bfa8275> in <module>
# ----> 1 cluster.close()
#
# NameError: name 'cluster' is not defined

# %%
client.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-1ef8b845d8fa> in <module>
# ----> 1 client.close()
#
# NameError: name 'client' is not defined

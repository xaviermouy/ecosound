# %%
import xarray

# %%
infile = r'C:\Users\xavier.mouy\Documents\PhD\Projects\Dectector\DFO_RCA_run\RCA_in_April_July2019_1342218252\summary\hourly_summary.nc'

# %%
ds = xarray.open_dataset(infile)
ds
# Out:
# <xarray.Dataset>
# Dimensions:     (confidence: 25, date: 1815)
# Coordinates:
#   * date        (date) datetime64[ns] 2019-04-10T15:00:00 ... 2019-06-25T05:0...
#   * confidence  (confidence) float64 0.5 0.52 0.54 0.56 ... 0.92 0.94 0.96 0.98
# Data variables:
#     FS          (confidence, date) float64 ...
#     NN          (confidence, date) float64 ...
